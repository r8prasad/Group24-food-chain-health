# %%
pwd
# Out:
# 'C:\\Users\\varad'

# %%
cd Github/src/plots
# Out:
# C:\Users\varad\Github\src\plots

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %%
import Price_comparison_healthy_unhealthy

# %%
from Price_comparison_healthy_unhealthy import *

# %%
data,layout = Price_plots()

# %%
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Avg Price Comparison')
# Out:
# F:\Python\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vajoshi/18.embed" height="525px" width="100%"></iframe>

# %%
import LocationDensityPlot
from LocationDensityPlot import *

# %%
restaurants = ['McDonald\'s', 'Pizza Hut', 'Domino\'s Pizza', 'Burger King', 'Chick-Fil-A', 'KFC']
goodOrBad = [-1,-1,-1,-1,-1,-1,-1]

#diabetes plot
locs(restaurants, goodOrBad, "Diabetes")

#heart disease plot
locs(restaurants, goodOrBad, "Heart Disease")

#obesity disease plot
locs(restaurants, goodOrBad, "Obesity")
# Out:
# C:\Users\varad\Github\src\plots\LocationDensityPlot.py:37: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from HealthyVsUnhealthy import *

# %%
main()
# Out:
# Processing info from restaurant -  DunkinDonuts
# Processing info from restaurant -  Dominos
# Processing info from restaurant -  ChickFilA
# Processing info from restaurant -  BurgerKing
# Processing info from restaurant -  Mcdonalds
# Processing info from restaurant -  PaneraBread
# Processing info from restaurant -  PizzaHut
# Processing info from restaurant -  KFC
# Processing info from restaurant -  Subway
# Processing info from restaurant -  PandaExpress
# F:\Python\lib\site-packages\matplotlib\legend.py:1270: UserWarning:
#
# You have mixed positional and keyword arguments, some input may be discarded.
